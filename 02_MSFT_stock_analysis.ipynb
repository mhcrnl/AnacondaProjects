# %% [markdown]
# # Stock Market Data Analysis
#
# - Get historical data for stocks
# - Plot the stock market data and analyse the performance
# - Get the fundamental, futures and options data
#
# You can use pandas_datareader or yfinance modules.
# ### Resurse:
# - [Blog](https://blog.quantinsti.com/stock-market-data-analysis-python/)
#
# - [yfinance](https://pypi.org/project/yfinance/)

# %%
# !pip install yfinance

# %%
import yfinance as yf
msft = yf.Ticker("MSFT")
print(msft)
# Out:
# yfinance.Ticker object <MSFT>

# %%
# get stock info
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
# ...

# %%
# get historical market data
hist = msft.history(period="max")

# %%
# show actions (dividents, splits)
msft.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-09-21       0.00           2.0
# 1990-04-16       0.00           2.0
# 1991-06-27       0.00           1.5
# 1992-06-15       0.00           1.5
# 1994-05-23       0.00           2.0
# ...               ...           ...
# 2020-08-19       0.51           0.0
# 2020-11-18       0.56           0.0
# 2021-02-17       0.56           0.0
# 2021-05-19       0.56           0.0
# 2021-08-18       0.56           0.0
#
# [80 rows x 2 columns]

# %%
# show dividends
msft.dividends
# Out:
# Date
# 2003-02-19    0.08
# 2003-10-15    0.16
# 2004-08-23    0.08
# 2004-11-15    3.08
# 2005-02-15    0.08
#               ...
# 2020-08-19    0.51
# 2020-11-18    0.56
# 2021-02-17    0.56
# 2021-05-19    0.56
# 2021-08-18    0.56
# Name: Dividends, Length: 71, dtype: float64

# %%
# show splits
msft.splits
# Out:
# Date
# 1987-09-21    2.0
# 1990-04-16    2.0
# 1991-06-27    1.5
# 1992-06-15    1.5
# 1994-05-23    2.0
# 1996-12-09    2.0
# 1998-02-23    2.0
# 1999-03-29    2.0
# 2003-02-18    2.0
# Name: Stock Splits, dtype: float64

# %%
# show financials
msft.financials
msft.quarterly_financials
# Out:
#                                            2021-09-30     2021-06-30  \
# Research Development                     5599000000.0   5687000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       20524000000.0  19405000000.0
# Minority Interest                                None           None
# Net Income                              20505000000.0  16458000000.0
# Selling General Administrative           5834000000.0   7379000000.0
# Gross Profit                            31671000000.0  32161000000.0
# Ebit                                    20238000000.0  19095000000.0
# Operating Income                        20238000000.0  19095000000.0
# Other Operating Expenses                         None           None
# Interest Expense                         -535000000.0   -549000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %%
# show major holders
msft.major_holders
# Out:
#         0                                      1
# 0   0.08%        % of Shares Held by All Insider
# 1  71.90%       % of Shares Held by Institutions
# 2  71.95%        % of Float Held by Institutions
# 3    5346  Number of Institutions Holding Shares

# %%
# show institutional holders
msft.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  610974647    2021-06-29  0.0814
# 1                     Blackrock Inc.  507117032    2021-09-29  0.0675
# 2           State Street Corporation  294824958    2021-06-29  0.0393
# 3                           FMR, LLC  218007132    2021-06-29  0.0290
# 4      Price (T.Rowe) Associates Inc  192408922    2021-06-29  0.0256
# 5      Geode Capital Management, LLC  123322145    2021-06-29  0.0164
# 6            Capital World Investors  110830050    2021-06-29  0.0148
# 7  Capital Research Global Investors   94576657    2021-06-29  0.0126
# 8    Capital International Investors   92898047    2021-06-29  0.0124
# 9         Northern Trust Corporation   88583941    2021-06-29  0.0118
#
#           Value
# 0  165513031872
# 1  142966433661
# 2   79868081122
# 3   59058132058
# 4   52123576969
# 5   33407969080
# 6   30023860545
# 7   25620816381
# 8   25166080932
# 9   23997389616

# %%
# show balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet
# Out:
#                                     2021-09-30    2021-06-30    2021-03-31  \
# Intangible Assets                 7.794000e+09  7.800000e+09  8.127000e+09
# Total Liab                        1.834400e+11  1.917910e+11  1.743740e+11
# Total Stockholder Equity          1.519780e+11  1.419880e+11  1.345050e+11
# Other Current Liab                5.262200e+10  5.261200e+10  4.006900e+10
# Total Assets                      3.354180e+11  3.337790e+11  3.088790e+11
# Common Stock                      8.375100e+10  8.311100e+10  8.230800e+10
# Other Current Assets              1.298200e+10  1.347100e+10  1.203400e+10
# Retained Earnings                 6.694400e+10  5.705500e+10  5.073500e+10
# Other Liab                        3.015700e+10  3.168100e+10  3.160100e+10
# Good Will                         5.045500e+10  4.971100e+10  4.969800e+10
# Treasury Stock                    1.283000e+09  1.822000e+09  1.462000e+09
# ...

# %%
# show cashflow
msft.cashflow
msft.quarterly_cashflow
# Out:
#                                              2021-09-30    2021-06-30  \
# Investments                                4.183000e+09 -4.334000e+09
# Change To Liabilities                     -3.356000e+09  1.301400e+10
# Total Cashflows From Investing Activities -3.250000e+09 -1.085300e+10
# Net Borrowings                            -4.826000e+09 -4.826000e+09
# Total Cash From Financing Activities      -1.627600e+10 -1.137100e+10
# Change To Operating Activities            -3.551000e+09  7.990000e+08
# Issuance Of Stock                          6.120000e+08  4.500000e+08
# Net Income                                 2.050500e+10  1.645800e+10
# Change In Cash                             4.941000e+09  5.220000e+08
# Repurchase Of Stock                       -7.684000e+09 -7.177000e+09
# Effect Of Exchange Rate                   -7.300000e+07  3.600000e+07
# Total Cash From Operating Activities       2.454000e+10  2.271000e+10
# ...

# %%
# show earnings
msft.earnings
msft.quarterly_earnings
# Out:
#              Revenue     Earnings
# Quarter
# 4Q2020   43076000000  15463000000
# 1Q2021   41706000000  15457000000
# 2Q2021   46152000000  16458000000
# 3Q2021   45317000000  20505000000

# %%
# show sustainability
msft.sustainability
# Out:
#                                      Value
# 2021-9
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                           8.06
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                      None
# peerCount                               99
# governanceScore                       4.73
# environmentPercentile                 None
# animalTesting                        False
# tobacco                              False
# totalEsg                             13.26
# highestControversy                       3
# esgPerformance                  UNDER_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...

# %%
# show analysts recommandetions
msft.recommendations
# Out:
#                                Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00  Argus Research            Buy                up
# 2012-03-19 14:00:00  Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00  Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00             UBS            Buy              main
# 2012-04-20 06:18:00   Deutsche Bank            Buy              main
# ...                             ...            ...        ...    ...
# 2021-10-27 12:37:42   Credit Suisse     Outperform              main
# 2021-10-27 13:41:53        Barclays     Overweight              main
# 2021-10-27 13:56:33  Morgan Stanley     Overweight              main
# 2021-10-28 14:55:44       Citigroup            Buy              main
# 2021-11-02 09:45:19   Deutsche Bank            Buy              init
#
# [358 rows x 4 columns]

# %%
# show next events (earnings, etc)
msft.calendar
# Out:
#                                     0                    1
# Earnings Date     2022-01-24 10:59:00  2022-01-28 12:00:00
# Earnings Average                 2.31                 2.31
# Earnings Low                     2.27                 2.27
# Earnings High                    2.46                 2.46
# Revenue Average           50807800000          50807800000
# Revenue Low               50511100000          50511100000
# Revenue High              51555000000          51555000000

# %%
# show ISIN code
msft.isin
# Out:
# 'US5949181045'

# %%
# show options expirations
msft.options
# Out:
# ('2021-11-19',
#  '2021-11-26',
#  '2021-12-03',
#  '2021-12-10',
#  '2021-12-17',
#  '2021-12-23',
#  '2021-12-31',
#  '2022-01-21',
#  '2022-02-18',
#  '2022-03-18',
#  '2022-04-14',
#  '2022-06-17',
#  '2022-09-16',
#  '2023-01-20',
#  '2023-03-17',
#  '2023-06-16',
#  '2024-01-19')

# %%
# show news
msft.news
# Out:
# [{'uuid': '50120fe9-fdd4-3f0f-af52-32562ec018d9',
#   'title': 'Europe’s Most Feared Investor Chris Hohn is Buying These 6 Stocks',
#   'publisher': 'Insider Monkey',
#   'link': 'https://finance.yahoo.com/news/europe-most-feared-investor-chris-204250396.html',
#   'providerPublishTime': 1636836170,
#   'type': 'STORY'},
#  {'uuid': 'dc38a3a6-0e14-3a45-b9e2-8be772e4ba68',
#   'title': 'Intel Stock: Bull vs. Bear',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/dc38a3a6-0e14-3a45-b9e2-8be772e4ba68/intel-stock%3A-bull-vs.-bear.html',
#   'providerPublishTime': 1636807020,
#   'type': 'STORY'},
#  {'uuid': '9115df95-df64-3265-bd43-0c271a7a56fb',
#   'title': 'What to know before making your holiday tech-stock wishlist',
#   'publisher': 'MarketWatch',
#   'link': 'https://finance.yahoo.com/m/9115df95-df64-3265-bd43-0c271a7a56fb/what-to-know-before-making.html',
#   'providerPublishTime': 1636750860,
#   'type': 'STORY'},
# ...

# %%
# get option chain for specific expirations
opt = msft.option_chain('2021-11-19')
print(opt)
# Out:
# Options(calls=         contractSymbol       lastTradeDate  strike  lastPrice     bid  \
# 0   MSFT211119C00120000 2021-10-19 13:44:26   120.0     188.65  215.95
# 1   MSFT211119C00125000 2021-11-10 11:46:30   125.0     166.70  211.05
# 2   MSFT211119C00130000 2021-10-18 14:23:16   130.0     173.90  205.95
# 3   MSFT211119C00135000 2021-11-04 17:24:48   135.0     201.35  200.95
# 4   MSFT211119C00140000 2021-11-10 11:46:30   140.0     148.10  196.05
# ..                  ...                 ...     ...        ...     ...
# 79  MSFT211119C00440000 2021-11-05 14:50:19   440.0       0.01    0.00
# 80  MSFT211119C00445000 2021-11-12 15:23:07   445.0       0.01    0.00
# 81  MSFT211119C00450000 2021-11-04 13:41:33   450.0       0.01    0.00
# 82  MSFT211119C00455000 2021-11-12 14:31:41   455.0       0.01    0.00
# 83  MSFT211119C00475000 2021-11-03 19:39:47   475.0       0.02    0.00
#
#        ask  change  percentChange  volume  openInterest  impliedVolatility  \
# ...

# %%
# set the start date and end date
start_date = '2021-01-01'
end_date = '2021-12-31'
# set the ticker
ticker = 'MSFT'
data = yf.download(ticker, start_date, end_date)
# print 5 rows
data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-11-08  337.299988  337.649994  334.440002  336.989990  336.989990
# 2021-11-09  337.109985  338.720001  334.529999  335.950012  335.950012
# 2021-11-10  334.570007  334.630005  329.920013  330.799988  330.799988
# 2021-11-11  331.250000  333.769989  330.510010  332.429993  332.429993
# 2021-11-12  333.920013  337.230011  333.790009  336.720001  336.720001
#
#               Volume
# Date
# 2021-11-08  20897000
# 2021-11-09  21307400
# 2021-11-10  25500900
# 2021-11-11  16849800
# 2021-11-12  23822000

# %%
# import matplotlib for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
# plot adjusted close price data
data['Adj Close'].plot()
plt.show()

# %%
# plot the adjusted close price
data['Adj Close'].plot(figsize=(10,7))
# define the label for title of the figure
plt.title("Adjusted Close Price of %s" %ticker, fontsize=16)
# define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel("Month", fontsize=14)
# plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

plt.show()
